# %% [markdown]
# <a href="https://colab.research.google.com/github/catastropiyush/course_notes/blob/main/Assignment2_Numerical_methods.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install smplotlib
import smplotlib
# Out:
# Collecting smplotlib
#   Downloading smplotlib-0.0.9-py3-none-any.whl.metadata (3.4 kB)
# Downloading smplotlib-0.0.9-py3-none-any.whl (424 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 424.1/424.1 kB 20.2 MB/s eta 0:00:00
# Installing collected packages: smplotlib
# Successfully installed smplotlib-0.0.9

# %% [markdown]
# https://web.njit.edu/~shahriar/class_home/Math453/power.pdf

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

def power_method(A, max_iter=100, tol=1e-10):
    n = A.shape[0]
    v = np.random.rand(n)        # Initialize random vector
    v = v / np.linalg.norm(v)

    lambda_old = 0
    for _ in range(max_iter):
        w = A @ v
        lambda_new = np.dot(w, v) / np.dot(v, v) #Rayleigh quotient
        v = w / np.linalg.norm(w) #Normalize vector

        if abs(lambda_new - lambda_old) < tol:
            return lambda_new, v
        lambda_old = lambda_new

    return lambda_new, v

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def inverse_power_method(A, max_iter=100, tol=1e-10):
    n = A.shape[0]
    v = np.random.rand(n)
    v = v / np.linalg.norm(v)

    lambda_old = 0
    for _ in range(max_iter):
        w = np.linalg.solve(A, v)
        lambda_new = np.dot(v, v) / np.dot(w, v)
        v = w / np.linalg.norm(w)

        if abs(lambda_new - lambda_old) < tol:
            return lambda_new, v
        lambda_old = lambda_new

    return lambda_new, v

# %%
A = np.array([
    [2, 8, 10],
    [8, 4, 5],
    [10, 5, 7]
])

#Power method
lambda_max, v_max = power_method(A)
print(f"Largest eigenvalue: {lambda_max:.6f}")
print(f"Corresponding eigenvector: {v_max}")

#Inverse power method
lambda_min, v_min = inverse_power_method(A)
print(f"\nSmallest eigenvalue: {lambda_min:.6f}")
print(f"Corresponding eigenvector: {v_min}")

# Verify results using numpy's eigvals function
true_eigenvals = np.linalg.eigvals(A)
print(f"\nTrue eigenvalues from numpy: {np.sort(true_eigenvals)}")
# Out:
# Largest eigenvalue: 19.884236
# Corresponding eigenvector: [0.58212798 0.49599473 0.64429516]
#
# Smallest eigenvalue: 0.294244
# Corresponding eigenvector: [-0.03202158 -0.77779682  0.62769955]
#
# True eigenvalues from numpy: [-7.1784802   0.29424417 19.88423603]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
    return x**4 - 2*x**3 + 6*x**2 - 2*x + 5

# Golden Search Method
def golden_search(f, a, b, tol=1e-6):
    gr = (np.sqrt(5) - 1) / 2    #Golden ratio
#This is actually (φ⁻¹), where φ is the golden ratio
    # Initialize points
    c = b - gr * (b - a)
    d = a + gr * (b - a)
    fc = f(c)
    fd = f(d)

#a -------- c -------- d -------- b
#|----------|----------|----------|
#    0.382      0.236      0.382    (proportions)
    while abs(b - a) > tol:
        if fc < fd:  # Minimum is in left interval
            b = d
            d = c
            fd = fc
            c = b - gr * (b - a)
            fc = f(c)
        else:  # Minimum is in right interval
            a = c
            c = d
            fc = fd
            d = a + gr * (b - a)
            fd = f(d)

    # Return the midpoint of the final interval
    x_min = (a + b) / 2
    return x_min, f(x_min)

x_min, f_min = golden_search(f, -1, 2)
print(f"Minimum found at x = {x_min:.6f}")
print(f"Minimum value = {f_min:.6f}")

x = np.linspace(-1, 2, 1000)
y = f(x)
plt.figure(figsize=(5,5))
plt.plot(x, y, 'b-', label='f(x)')
plt.plot(x_min, f_min, 'ro', label='Minimum')
plt.grid(True)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
# Out:
# Minimum found at x = 0.181083
# Minimum value = 4.823780

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
    return 3 + 6*x + 5*x**2 + 3*x**3 + 4*x**4

def f_prime(x):
    return 6 + 10*x + 9*x**2 + 16*x**3

def f_double_prime(x):
    return 10 + 18*x + 48*x**2

def newton_method(x0, es=0.01, max_iter=100):
    x_history = [x0]
    f_history = [f(x0)]

    x_old = x0
    iter_count = 0
    ea = 100  # initial error estimate

    while ea > es and iter_count < max_iter:
        x_new = x_old - f_prime(x_old)/f_double_prime(x_old)

        if x_new != 0:
            ea = abs((x_new - x_old)/x_new) * 100

        x_old = x_new
        iter_count += 1

        x_history.append(x_new)
        f_history.append(f(x_new))

        print(f"Iteration {iter_count}: x = {x_new:.6f}, f(x) = {f(x_new):.6f}, Error = {ea:.6f}%")

    return x_history, f_history

# Initial parameters
x0 = -1      # Initial guess
es = 1.0     # Stopping criterion (1%)

x_history, f_history = newton_method(x0, es)
# Final results
x_min = x_history[-1]
f_min = f_history[-1]

print("\nFinal Results:")
print(f"Minimum found at x = {x_min:.6f}")
print(f"Minimum value = {f_min:.6f}")
# Out:
# Iteration 1: x = -0.725000, f(x) = 1.240017, Error = 37.931034%
# Iteration 2: x = -0.607028, f(x) = 1.072327, Error = 19.434412%
# Iteration 3: x = -0.587172, f(x) = 1.068971, Error = 3.381640%
# Iteration 4: x = -0.586683, f(x) = 1.068969, Error = 0.083350%
#
# Final Results:
# Minimum found at x = -0.586683
# Minimum value = 1.068969

# %%
def plot_results():
    x = np.linspace(min(x_history)-0.5, max(x_history)+0.5, 1000)
    y = f(x)
    plt.plot(x, y, 'b-', label='f(x)')
    plt.plot(x_history, f_history, 'ro-', label='Iterations')
    plt.plot(x_min, f_min, 'go', label='Minimum')
    plt.grid(True)
    plt.title('Function and Newton Method Iterations')
    plt.xlabel('x')
    plt.ylabel('f(x)')
    plt.legend()

plot_results()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

def f(x):
    return -2 + 6.2*x - 4*x**2 + 0.9*x**3

def quadratic_interpolation(x0, x1, x2):
    y0, y1, y2 = f(x0), f(x1), f(x2)
    a = (x0*(y2-y1) + x1*(y0-y2) + x2*(y1-y0))/((x0-x1)*(x0-x2)*(x1-x2))
    b = (y2-y1)/(x2-x1) - a*(x1+x2)
    x_vertex = -b/(2*a)

    return x_vertex

# Initial guess points
x0, x1, x2 = 0, 1, 2

# Plotting
x = np.linspace(-1, 3, 1000)
y = f(x)

# Plot the function
plt.figure(figsize=(8, 6))
plt.plot(x, y, 'b-', label='f(x)')

# Find derivative
def df(x):
    return 6.2 - 8*x + 2.7*x**2

# Find actual maximum using derivative
x_max = fsolve(lambda x: df(x), 1)[0]
y_max = f(x_max)

# Perform quadratic interpolation
x_approx = quadratic_interpolation(x0, x1, x2)
y_approx = f(x_approx)


plt.plot(x_max, y_max, 'r*', markersize=15, label='True Maximum')
plt.plot(x_approx, y_approx, 'g*', markersize=15, label='Approximated Maximum')
plt.plot([x0, x1, x2], [f(x0), f(x1), f(x2)], 'ko', label='Interpolation Points')

plt.grid(True)
plt.legend()
plt.title('Quadratic Interpolation Method')
plt.xlabel('x')
plt.ylabel('f(x)')

# Print results
print(f"Actual maximum occurs at x = {x_max:.6f}")
print(f"Function value at maximum: {y_max:.6f}")
print(f"\nApproximated maximum occurs at x = {x_approx:.6f}")
print(f"Function value at approximated maximum: {y_approx:.6f}")
print(f"\nAbsolute error in x: {abs(x_max - x_approx):.6f}")
print(f"Absolute error in f(x): {abs(y_max - y_approx):.6f}")

plt.show()
# Out:
# Actual maximum occurs at x = 1.481597
# Function value at maximum: 1.332450
#
# Approximated maximum occurs at x = 1.692308
# Function value at approximated maximum: 1.398635
#
# Absolute error in x: 0.210711
# Absolute error in f(x): 0.066184

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data
Y = np.array([159, 179, 100, 45, 384, 230, 100, 320, 80, 220, 320, 210]).reshape(-1,1)
X_raw = np.array([14.40, 15.20, 11.30, 2.50, 22.70, 14.90, 1.41, 15.81, 4.19, 15.39, 17.25, 9.52])

# Add column of ones for intercept term
X = np.column_stack([np.ones_like(X_raw), X_raw])

X_transpose = np.transpose(X)                        # Xᵀ
X_transpose_X = np.dot(X_transpose, X)               # XᵀX
X_transpose_X_inv = np.linalg.inv(X_transpose_X)     # (XᵀX)⁻¹
X_transpose_Y = np.dot(X_transpose, Y)           # XᵀY
beta = np.dot(X_transpose_X_inv, X_transpose_Y)   # β = (XᵀX)⁻¹XᵀY

Y_pred = np.dot(X, beta)  # ŷ = β₀ + β₁x
residuals = Y - Y_pred    # εᵢ = yᵢ - ŷᵢ

SS_tot = np.sum((Y - np.mean(Y))**2)   # Total Sum of Squares: Σ(yᵢ - ȳ)²
SS_res = np.sum(residuals**2)          # Residual Sum of Squares: Σ(yᵢ - ŷᵢ)²
R_squared = 1 - (SS_res/SS_tot)        # R² = 1 - SSres/SStot

# Calculate standard errors for coefficients
n = len(Y)
p = X.shape[1]  # number of parameters

MSE = SS_res / (n - p)                 # σ² estimate
var_beta = MSE * X_transpose_X_inv     # Var(β) = σ²(XᵀX)⁻¹
std_errors = np.sqrt(np.diag(var_beta)) # SE(β) = √diag(Var(β))

# %%
# Create subplots
plt.figure(figsize=(15, 5))

# 1. Scatter plot with regression line
plt.subplot(1, 2, 1)
plt.scatter(X_raw, Y, color='blue', alpha=0.5, label='Observed Data')
X_line = np.array([min(X_raw), max(X_raw)])
Y_line = beta[0] + beta[1] * X_line
plt.plot(X_line, Y_line, color='red',
         label=f'Regression Line\ny = {beta[0][0]:.2f} + {beta[1][0]:.2f}x')
plt.xlabel('Body Weight (g)')
plt.ylabel('Gill Weight (mg)')
plt.title('Scatter Plot with Regression Line')
plt.legend()
plt.grid(True, alpha=0.3)

# 2. Residual plot
plt.subplot(1, 2, 2)
plt.scatter(Y_pred, residuals, color='green', alpha=0.5)
plt.axhline(y=0, color='red', linestyle='--')
plt.xlabel('Predicted Gill Weight (mg)')
plt.ylabel('Residuals')
plt.title('Residual Plot')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

print(f"Intercept (β₀): {beta[0][0]:.4f}")
print(f"Slope (β₁): {beta[1][0]:.4f}")
print(f"β₀: {std_errors[0]:.4f}")
print(f"β₁: {std_errors[1]:.4f}")

# Additional matrix calculations
print("\nVariance-Covariance Matrix:")
print(var_beta)
# Out:
# Intercept (β₀): 24.6540
# Slope (β₁): 14.1879
# β₀: 35.2430
# β₁: 2.6004
#
# Variance-Covariance Matrix:
# [[1242.06811613  -81.46583118]
#  [ -81.46583118    6.76205281]]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

def divided_differences(x, y):
    n = len(x)
    coef = np.zeros([n, n])
    coef[:,0] = y

    for j in range(1,n):
        for i in range(n-j):
            coef[i][j] = (coef[i+1][j-1] - coef[i][j-1]) / (x[i+j] - x[i])

    return coef

def newton_interpolation(x_data, y_data, x):
    n = len(x_data)
    coef = divided_differences(x_data, y_data)

    result = coef[0][0]
    temp = 1
    for j in range(1, n):
        temp *= (x - x_data[j-1])
        result += coef[0][j] * temp

    return result

def lagrange_interpolation(x_data, y_data, x):
    n = len(x_data)
    result = 0

    for i in range(n):
        term = y_data[i]
        for j in range(n):
            if j != i:
                term *= (x - x_data[j]) / (x_data[i] - x_data[j])
        result += term

    return result

# Data points
x_data = np.array([1.6, 2.0, 2.5, 3.2,4,4.5])
y_data = np.array([2,8,14,15,8,2])
x_interpolate = 2.7

# Calculate using both methods
newton_result = newton_interpolation(x_data, y_data, x_interpolate)
lagrange_result = lagrange_interpolation(x_data, y_data, x_interpolate)

print(f"Newton's Interpolation f(2.7) = {newton_result:.4f}")
print(f"Lagrange's Interpolation f(2.7) = {lagrange_result:.4f}")

# Verify they give the same result
print(f"\nDifference between methods: {abs(newton_result - lagrange_result):.10f}")
